# %% [markdown]
# # 02 · RFM Table, Scoring & Segmentation
#
# - **Recency** = days since last *purchase* (from sales lines only).
# - **Frequency** = number of unique purchase invoices.
# - **Monetary** = total spend **net of returns**.
#
# Each dimension is scored 1–5 with quintiles (`qcut` on the rank, so bins are balanced even with ties). Frequency and Monetary are combined into a single **FM** score, and customers are mapped to segments using a standard Recency × FM matrix (no ambiguous 'Others' bucket).

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../Data/Processed/transactions_clean.csv")
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])
df.shape
# Out:
# (399656, 10)

# %% [markdown]
# ### Build the RFM table

# %%
sales = df[~df["IsReturn"]]
reference_date = sales["InvoiceDate"].max() + pd.Timedelta(days=1)
print("Reference date:", reference_date)

# Recency & Frequency from purchases only
rfm = sales.groupby("CustomerID").agg(
    Recency=("InvoiceDate", lambda x: (reference_date - x.max()).days),
    Frequency=("InvoiceNo", "nunique"),
).reset_index()

# Monetary = net spend (sales minus returns)
net_monetary = df.groupby("CustomerID")["TotalPrice"].sum().round(2).rename("Monetary")
rfm = rfm.merge(net_monetary, on="CustomerID", how="left")

# drop net-zero / net-negative customers (returned as much or more than they bought)
before = len(rfm)
rfm = rfm[rfm["Monetary"] > 0].reset_index(drop=True)
print(f"Dropped {before - len(rfm)} net-<=0 customers")
print("Customers:", len(rfm))
rfm.describe()
# Out:
# Reference date: 2011-12-10 12:50:00
# Dropped 14 net-<=0 customers
# Customers: 4320
#          CustomerID      Recency    Frequency       Monetary
# count   4320.000000  4320.000000  4320.000000    4320.000000
# mean   15300.771065    92.549074     4.256019    1914.267898
# std     1720.217887   100.120039     7.645280    8303.784608
# min    12347.000000     1.000000     1.000000       2.900000
# 25%    13815.750000    18.000000     1.000000     299.045000
# 50%    15299.500000    51.000000     2.000000     650.420000
# 75%    16778.250000   143.000000     5.000000    1610.457500
# max    18287.000000   374.000000   206.000000  278778.020000

# %%
rfm.to_csv("../Data/Processed/rfm_table.csv", index=False)
print("Saved ../Data/Processed/rfm_table.csv")
# Out:
# Saved ../Data/Processed/rfm_table.csv

# %% [markdown]
# ### Score R, F, M into quintiles (1–5)
# Ranking before `qcut` guarantees five equal-sized bins even though Recency/Frequency have many tied values.

# %%
rfm["R_score"] = pd.qcut(rfm["Recency"].rank(method="first"),   5, labels=[5,4,3,2,1]).astype(int)
rfm["F_score"] = pd.qcut(rfm["Frequency"].rank(method="first"), 5, labels=[1,2,3,4,5]).astype(int)
rfm["M_score"] = pd.qcut(rfm["Monetary"].rank(method="first"),  5, labels=[1,2,3,4,5]).astype(int)

rfm["RFM_score"] = rfm["R_score"].astype(str) + rfm["F_score"].astype(str) + rfm["M_score"].astype(str)
# combined Frequency+Monetary score used for the segment matrix
rfm["FM"] = np.ceil((rfm["F_score"] + rfm["M_score"]) / 2).clip(1,5).astype(int)

for c in ["R_score","F_score","M_score"]:
    print(c, rfm[c].value_counts().sort_index().to_dict())
rfm.head()
# Out:
# R_score {1: 864, 2: 864, 3: 864, 4: 864, 5: 864}
# F_score {1: 864, 2: 864, 3: 864, 4: 864, 5: 864}
# M_score {1: 864, 2: 864, 3: 864, 4: 864, 5: 864}
#    CustomerID  Recency  Frequency  Monetary  R_score  F_score  M_score  \
# 0       12347        2          7   4310.00        5        5        5
# 1       12348       75          4   1437.24        2        4        4
# 2       12349       19          1   1457.55        4        1        4
# 3       12350      310          1    294.40        1        1        2
# 4       12352       36          7   1265.41        3        5        4
#
#   RFM_score  FM
# 0       555   5
# 1       244   4
# 2       414   3
# 3       112   2
# 4       354   5

# %% [markdown]
# ### Assign segments (Recency × FM matrix)
# Every customer maps to exactly one segment — the rules are exhaustive, so there is no catch-all bucket.

# %%
def segment(r, fm):
    if r >= 4 and fm >= 4: return "Champions"
    if r >= 3 and fm >= 3: return "Loyal Customers"
    if r >= 4 and fm >= 2: return "Potential Loyalists"
    if r >= 4:             return "New Customers"       # recent but very low value
    if r == 3:             return "Promising"           # mid recency, low value
    if r == 2 and fm >= 3: return "At Risk"
    if r == 1 and fm >= 4: return "Cant Lose Them"
    if r == 1 and fm == 3: return "At Risk"
    if r == 2:             return "About to Sleep"
    return "Hibernating"                               # r == 1 and fm <= 2

rfm["Segment"] = rfm.apply(lambda x: segment(x["R_score"], x["FM"]), axis=1)
rfm["Segment"].value_counts()
# Out:
# Segment
# Champions              1166
# Loyal Customers         852
# At Risk                 703
# Hibernating             609
# About to Sleep          338
# Promising               293
# Potential Loyalists     211
# Cant Lose Them           78
# New Customers            70
# Name: count, dtype: int64

# %%
rfm.to_csv("../Data/Processed/rfm_scored_segments.csv", index=False)
print("Saved ../Data/Processed/rfm_scored_segments.csv")
# Out:
# Saved ../Data/Processed/rfm_scored_segments.csv

# %% [markdown]
# ### Segment summary

# %%
segment_summary = (
    rfm.groupby("Segment").agg(
        Customers=("CustomerID", "count"),
        Avg_Recency=("Recency", "mean"),
        Avg_Frequency=("Frequency", "mean"),
        Avg_Monetary=("Monetary", "mean"),
        Total_Revenue=("Monetary", "sum"),
    )
    .sort_values("Total_Revenue", ascending=False)
    .round(2)
)
segment_summary.to_csv("../Data/Processed/segment_summary.csv")
segment_summary
# Out:
#                      Customers  Avg_Recency  Avg_Frequency  Avg_Monetary  \
# Segment
# Champions                 1166        13.13           9.67       4933.50
# Loyal Customers            852        38.80           3.55       1366.08
# At Risk                    703       146.36           2.92       1123.46
# Cant Lose Them              78       234.81           4.06       2252.59
# Hibernating                609       278.03           1.07        235.75
# About to Sleep             338       120.20           1.14        278.76
# Promising                  293        52.29           1.12        272.10
# Potential Loyalists        211        17.38           1.32        282.57
# New Customers               70        18.60           1.00        152.04
#
#                      Total_Revenue
# Segment
# Champions               5752459.84
# Loyal Customers         1163898.25
# At Risk                  789791.49
# Cant Lose Them           175701.67
# Hibernating              143571.87
# ...

# %% [markdown]
# ### Figures

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

fig_dir = Path("../Reports/Figures")
fig_dir.mkdir(parents=True, exist_ok=True)
order = rfm["Segment"].value_counts().index

# 1) customer count by segment
plt.figure(figsize=(11,5))
sns.countplot(data=rfm, x="Segment", order=order, color="#4C78A8")
plt.xticks(rotation=30, ha="right"); plt.title("Customer count by segment"); plt.tight_layout()
plt.savefig(fig_dir / "segment_counts.png", dpi=200); plt.close()

# 2) total revenue by segment
revenue = rfm.groupby("Segment")["Monetary"].sum().sort_values(ascending=False)
plt.figure(figsize=(11,5))
sns.barplot(x=revenue.index, y=revenue.values, color="#54A24B")
plt.xticks(rotation=30, ha="right"); plt.ylabel("Revenue (net Monetary)")
plt.title("Total revenue by segment"); plt.tight_layout()
plt.savefig(fig_dir / "segment_revenue.png", dpi=200); plt.close()

# 3) heatmap of average R/F/M scores per segment
avg_scores = rfm.groupby("Segment")[["R_score","F_score","M_score"]].mean().loc[order]
plt.figure(figsize=(6,5))
sns.heatmap(avg_scores, annot=True, fmt=".2f", cmap="Blues")
plt.title("Average R/F/M scores per segment"); plt.tight_layout()
plt.savefig(fig_dir / "segment_avg_scores_heatmap.png", dpi=200); plt.close()
print("Saved 3 figures to", fig_dir)
# Out:
# Saved 3 figures to ..\Reports\Figures
