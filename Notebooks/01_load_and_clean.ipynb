# %% [markdown]
# # 01 · Load & Clean
# Clean the UCI Online Retail transactions so we can build an RFM table.
#
# **Cleaning steps**
# 1. Drop rows with no `CustomerID` (can't attribute to a customer).
# 2. Drop exact duplicate rows.
# 3. Drop non-product service codes (postage, bank charges, manual adjustments, gift-card, etc.) — keep only `StockCode`s that start with 5 digits.
# 4. Drop rows with `UnitPrice <= 0`.
# 5. Flag returns (`Quantity < 0` or `InvoiceNo` starting with `C`) so Monetary can be **netted** later.

# %%
import pandas as pd
import numpy as np

path = "../Data/Raw/Online Retail.xlsx"
df = pd.read_excel(path)
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])
print(df.shape)
df.info()
# Out:
# (541909, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# ### Data-quality checks (before cleaning)

# %%
print("Null CustomerID:", df["CustomerID"].isna().sum())
print("Exact duplicate rows:", df.duplicated().sum())
print("Cancellations (InvoiceNo starts with C):", df["InvoiceNo"].astype(str).str.startswith("C").sum())
print("Quantity <= 0:", (df["Quantity"] <= 0).sum())
print("UnitPrice <= 0:", (df["UnitPrice"] <= 0).sum())
sc = df["StockCode"].astype(str)
print("Non-product (service) codes:", (~sc.str.match(r"^\d{5}")).sum())
df[~sc.str.match(r"^\d{5}")]["StockCode"].astype(str).value_counts().head(10)
# Out:
# Null CustomerID: 135080
# Exact duplicate rows: 5268
# Cancellations (InvoiceNo starts with C): 9288
# Quantity <= 0: 10624
# UnitPrice <= 0: 2517
# Non-product (service) codes: 2995
# StockCode
# POST            1256
# DOT              710
# M                571
# C2               144
# D                 77
# S                 63
# BANK CHARGES      37
# AMAZONFEE         34
# CRUK              16
# DCGSSGIRL         13
# Name: count, dtype: int64

# %% [markdown]
# ### Apply cleaning

# %%
clean = df.copy()

# 1) drop rows without a customer id
clean = clean.dropna(subset=["CustomerID"])

# 2) drop exact duplicate rows
clean = clean.drop_duplicates()

# 3) keep only product stock codes (start with 5 digits) -> drops POST, DOT, M, BANK CHARGES, gift_*, DCGS*, etc.
sc = clean["StockCode"].astype(str)
clean = clean[sc.str.match(r"^\d{5}")]

# 4) drop non-positive prices
clean = clean[clean["UnitPrice"] > 0]

# types + derived columns
clean["CustomerID"] = clean["CustomerID"].astype(int)
clean["IsReturn"] = (clean["Quantity"] < 0) | (clean["InvoiceNo"].astype(str).str.startswith("C"))
clean["TotalPrice"] = (clean["Quantity"] * clean["UnitPrice"]).round(2)

print("Rows after cleaning:", clean.shape)
print("  sales lines :", (~clean["IsReturn"]).sum())
print("  return lines:", clean["IsReturn"].sum())
clean.head()
# Out:
# Rows after cleaning: (399656, 10)
#   sales lines : 391150
#   return lines: 8506
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  IsReturn  \
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom     False
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom     False
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom     False
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom     False
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom     False
#
#    TotalPrice
# 0       15.30
# ...

# %%
clean["InvoiceDate"].min(), clean["InvoiceDate"].max()
# Out:
# (Timestamp('2010-12-01 08:26:00'), Timestamp('2011-12-09 12:50:00'))

# %% [markdown]
# Save the cleaned line-item table. It keeps **both** sales and return lines (flagged via `IsReturn`) so the RFM notebook can net returns out of Monetary.

# %%
clean.to_csv("../Data/Processed/transactions_clean.csv", index=False)
print("Saved ../Data/Processed/transactions_clean.csv", clean.shape)
# Out:
# Saved ../Data/Processed/transactions_clean.csv (399656, 10)
