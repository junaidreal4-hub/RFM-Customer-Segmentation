# %% [markdown]
# # 04 · SQL Analysis (SQLite)
#
# Load the **real** scored RFM table into SQLite and answer business questions with SQL. Segment counts here match notebook 02 exactly because we query the segment labels produced there (rather than a second, divergent set of rules).

# %%
import pandas as pd
import sqlite3

rfm = pd.read_csv("../Data/Processed/rfm_scored_segments.csv")
print("Loaded", len(rfm), "customers")
conn = sqlite3.connect("../Data/Processed/rfm_database.db")
rfm.to_sql("customers", conn, if_exists="replace", index=False)
print("Wrote table 'customers'")
# Out:
# Loaded 4320 customers
# Wrote table 'customers'

# %% [markdown]
# ### Recency buckets

# %%
query = '''
SELECT
    CASE
        WHEN Recency <= 30  THEN 'Very Recent (0-30)'
        WHEN Recency <= 90  THEN 'Recent (31-90)'
        WHEN Recency <= 180 THEN 'Lapsing (91-180)'
        ELSE 'Dormant (180+)'
    END AS RecencyGroup,
    COUNT(*)                 AS CustomerCount,
    ROUND(AVG(Frequency),1)  AS AvgFrequency,
    ROUND(AVG(Monetary),2)   AS AvgSpend,
    ROUND(SUM(Monetary),2)   AS TotalRevenue
FROM customers
GROUP BY RecencyGroup
ORDER BY MIN(Recency);
'''
pd.read_sql_query(query, conn)
# Out:
#          RecencyGroup  CustomerCount  AvgFrequency  AvgSpend  TotalRevenue
# 0  Very Recent (0-30)           1645           7.2   3559.27    5855000.71
# 1      Recent (31-90)           1232           3.1   1233.15    1519235.49
# 2    Lapsing (91-180)            586           2.3    775.60     454504.42
# 3      Dormant (180+)            857           1.5    514.47     440896.70

# %% [markdown]
# ### Top 10 VIP customers by net spend

# %%
query = '''
SELECT CustomerID,
       Recency  AS DaysSinceLastPurchase,
       Frequency AS Orders,
       ROUND(Monetary,2) AS NetSpend,
       Segment
FROM customers
ORDER BY Monetary DESC
LIMIT 10;
'''
pd.read_sql_query(query, conn)
# Out:
#    CustomerID  DaysSinceLastPurchase  Orders   NetSpend          Segment
# 0       14646                      2      72  278778.02        Champions
# 1       18102                      1      60  259657.30        Champions
# 2       17450                      8      46  189575.53        Champions
# 3       14911                      1     198  128768.24        Champions
# 4       12415                     24      20  123638.18        Champions
# 5       14156                     10      54  113685.77        Champions
# 6       17511                      3      31   88138.20        Champions
# 7       16684                      4      28   65920.12        Champions
# 8       13694                      4      50   62961.54        Champions
# 9       16029                     39      62   60369.93  Loyal Customers

# %% [markdown]
# ### Overall RFM statistics

# %%
query = '''
SELECT COUNT(*) AS TotalCustomers,
       ROUND(AVG(Recency),1)   AS AvgRecency,
       ROUND(AVG(Frequency),1) AS AvgFrequency,
       ROUND(AVG(Monetary),2)  AS AvgMonetary,
       ROUND(SUM(Monetary),2)  AS TotalRevenue
FROM customers;
'''
pd.read_sql_query(query, conn)
# Out:
#    TotalCustomers  AvgRecency  AvgFrequency  AvgMonetary  TotalRevenue
# 0            4320        92.5           4.3      1914.27    8269637.32

# %% [markdown]
# ### Segment distribution & revenue (matches notebook 02)

# %%
query = '''
SELECT Segment,
       COUNT(*)                                            AS Customers,
       ROUND(100.0*COUNT(*)/(SELECT COUNT(*) FROM customers),1) AS PctOfCustomers,
       ROUND(AVG(Monetary),2)                              AS AvgSpend,
       ROUND(SUM(Monetary),2)                              AS TotalRevenue,
       ROUND(100.0*SUM(Monetary)/(SELECT SUM(Monetary) FROM customers),1) AS PctOfRevenue
FROM customers
GROUP BY Segment
ORDER BY TotalRevenue DESC;
'''
pd.read_sql_query(query, conn)
# Out:
#                Segment  Customers  PctOfCustomers  AvgSpend  TotalRevenue  \
# 0            Champions       1166            27.0   4933.50    5752459.84
# 1      Loyal Customers        852            19.7   1366.08    1163898.25
# 2              At Risk        703            16.3   1123.46     789791.49
# 3       Cant Lose Them         78             1.8   2252.59     175701.67
# 4          Hibernating        609            14.1    235.75     143571.87
# 5       About to Sleep        338             7.8    278.76      94222.51
# 6            Promising        293             6.8    272.10      79726.33
# 7  Potential Loyalists        211             4.9    282.57      59622.68
# 8        New Customers         70             1.6    152.04      10642.68
#
#    PctOfRevenue
# 0          69.6
# 1          14.1
# 2           9.6
# 3           2.1
# 4           1.7
# 5           1.1
# 6           1.0
# 7           0.7
# 8           0.1

# %% [markdown]
# ### Reproduce the R/F/M scores in pure SQL with `NTILE`
# This confirms the quintile scoring is reproducible in SQL and lines up with the pandas scores.

# %%
query = '''
SELECT CustomerID, Recency, Frequency, Monetary,
       NTILE(5) OVER (ORDER BY Recency DESC)  AS R_sql,
       NTILE(5) OVER (ORDER BY Frequency ASC) AS F_sql,
       NTILE(5) OVER (ORDER BY Monetary ASC)  AS M_sql
FROM customers
LIMIT 10;
'''
pd.read_sql_query(query, conn)
# Out:
#    CustomerID  Recency  Frequency  Monetary  R_sql  F_sql  M_sql
# 0       13747      374          1     79.60      1      1      1
# 1       12791      374          1    177.60      1      1      1
# 2       17908      374          1    232.03      1      1      1
# 3       16583      374          1    233.45      1      1      1
# 4       17968      374          1    265.10      1      1      2
# 5       14729      374          1    313.49      1      2      2
# 6       18074      374          1    489.60      1      2      3
# 7       12855      373          1     38.10      1      1      1
# 8       17643      373          1    101.55      1      1      1
# 9       18011      373          1    102.79      1      1      1

# %%
conn.close()
print("Connection closed")
# Out:
# Connection closed
